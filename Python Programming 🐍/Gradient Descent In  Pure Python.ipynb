# %% [markdown]
# # Gradient Descent In Pure Python

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Gradient decent of this function = $ f(x) = x^4 - 3x^3 + 2$

# %%
#create function and plot
function = lambda x: pow(x,4) - (3*(x ** 3)) + 2

# create 1000 even spaced numbers between -3 and 5
x = np.linspace(-3,5,500)

# plot
plt.plot(x, function(x))
plt.show()

# %%
def deriv(x): 
    '''
    x - a numerical value of x 
    x_deriv - a numerical value of the derivative of x
    '''
    
    x_deriv = 3 * (x**2) - (6 * (x))
    return x_deriv


def step(x_new, x_prev, precision, eta):
    '''
    x_new - a starting value of x that will get updated based on the learning rate
    x_prev - the previous value of x that is getting updated to the new one
    precision - a precision that determines the stop of the stepwise descent 
    eta - the learning rate (size of each descent step)
    '''
    
    # create empty lists for updated values of x and y wil be appended
    x_list, y_list = [x_new], [function(x_new)]
    # keep looping until your desired precision
    while abs(x_new - x_prev) > precision:
        
        # change the value of x
        x_prev = x_new
        
        # get the derivation of the old value of x
        d_x = - deriv(x_prev)
        
        # get your new value of x by adding the previous, the multiplication of the derivative and the learning rate
        x_new = x_prev + (eta * d_x)
        
        # append the new value of x to a list of all x-s for later visualization of path
        x_list.append(x_new)
        
        # append the new value of y to a list of all y-s for later visualization of path
        y_list.append(function(x_new))

    print (f'Local minimum occurs at: {x_new}')
    print (f'Number of steps: {np.round(x_list, 3)}')
    
    plt.subplot(1,2,2)
    plt.scatter(x_list,y_list,c="g")
    plt.plot(x_list,y_list,c="g")
    plt.plot(x,function(x), c="r")
    plt.title("Gradient descent")
    plt.show()

    plt.subplot(1,2,1)
    plt.scatter(x_list,y_list,c="g")
    plt.plot(x_list,y_list,c="g")
    plt.plot(x,function(x), c="r")
    plt.xlim([1.0,2.1])
    plt.title("Zoomed in Gradient descent")
    plt.show()

# %%
# gradient descent
step(0.5, 0, 0.001, 0.05)
# x_new, x_prev, precision, eta
# Out:
# Local minimum occurs at: 1.9980265135950486
# Number of steps: [0.5   0.612 0.74  0.88  1.028 1.178 1.323 1.457 1.576 1.676 1.758 1.821
#  1.87  1.907 1.933 1.953 1.967 1.976 1.983 1.988 1.992 1.994 1.996 1.997
#  1.998]
